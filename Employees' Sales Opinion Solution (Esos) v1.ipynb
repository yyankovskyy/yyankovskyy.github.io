# %%
"""
Created on Mon Feb  6 09:14:13 2017
@author: eyankovsky

The goals of this solution are 
1) Collect employee's opinion on sales of the items in the store s/he works at
2) Provide a report to the store manager on the items identified by their employees. 
So, the manager will be able 
a) to compare actual item sales to their inventories (or sales forecast), 
b) to make decision on making changes inventories forecasts.

The solution works only with a test case using hard coded mock data:


Enter commodity you want to talk about
> A1

Enter your Kohl's employee ID
> 1111

What is the start of the period you wanted to talk about in format
  MM-DD-YYYY?
> 01-01-2016

What is the end of the period you wanted to talk about in format
  MM-DD-YYYY?
> 02-01-2017

What is your openion on sales of this item? 
 a) Well 
 b) Poorly 
 
>  Poorly # Any entry can be provided
 
Please, provide your free text feedback 
> The design does not appeal # Any entry can be provided
    
"""

def Esos_function():
    import IPython.core.display as di
    di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
    di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)

 

    import pandas as pd
    import numpy as np
    import datetime

    Esos_data = np.zeros((1,), dtype=[('Employee_ID', 'a10'),('Item_ID', 'a10'),('Start_Date', 'M'),('End_Date', 'M'),('Employee_Openion', 'a10')])                                
    Esos = pd.DataFrame(Esos_data)
    
    print ("Hi, \nWelcome to Kohl's!")
    print ('We need to know your openion on sales in your department to account for it in our re-stocking plans.')
    
    Esos['Item_ID'] = input('Enter commodity you want to talk about\n > ')
    Esos['Employee_ID']= input("Enter your Kohl's employee ID\n > ")
    
    Start_Date = input('What is the start of the period you wanted to talk about in format \n   MM-DD-YYYY?\n > ')
    Esos['Start_Date'] = datetime.datetime.strptime(Start_Date, '%m-%d-%Y')
    
    End_Date =  input('What is the end of the period you wanted to talk about in format \n   MM-DD-YYYY?\n > ')
    Esos['End_Date'] = datetime.datetime.strptime(End_Date, '%m-%d-%Y')
    
    Esos['Employee_Openion'] = input('What is your openion on sales of this item? \n a) Well \n b) Poorly \n>   ')
    Esos['Employee_Openion_text'] = input('Please, provide your free text feedback \n>   ')

    #print('Esos tabel')
    #Esos.head()

    PDB_data = np.zeros((1,), dtype=[('Store_Name', 'a10'), ('Store_ID', 'a10'), ('Store_Street_Address', 'a10'),('Store_State', 'a10'), ('Store_City', 'a10'),('Store_Postal_Code', 'a10'),('Employee_ID', 'a10'),('Employee_First_Name', 'a10'),('Employee_Middle_Name', 'a10'),('Employee_Last_Name', 'a10'),('PDB_Data_Entry_Date', 'M')])

    PDB = pd.DataFrame(PDB_data)


    PDB.loc[0,'Store_Name'] = 'San Jose South'
    PDB.loc[0,'Store_ID'] ='1'
    PDB.loc[0,'Store_Street_Address'] = '890 Blossom Hill Rd'
    PDB.loc[0,'Store_State'] ='CA'
    PDB.loc[0,'Store_City'] ='San Jose'
    PDB.loc[0,'Store_Postal_Code'] ='95123'

    PDB.loc[0,'Employee_ID'] = '1111'
    PDB.loc[0,'Employee_First_Name'] = 'John'
    PDB.loc[0,'Employee_Middle_Name'] = 'Adam'
    PDB.loc[0,'Employee_Last_Name'] = 'Smith'
    PDB.loc[0,'PDB_Data_Entry_Date'] = datetime.datetime.strptime('2017-02-01', '%Y-%m-%d')

    GIV_data = np.zeros((3,), dtype=[('Store_ID', 'a10'), ('Item_ID', 'a10'), ('Item_Name', 'a10'),('Item_Price', 'f4'), ('Item_Discount', 'f4'),('Item_Quantity_Sold', 'f4'),('Item_Quantity_Ordered', 'f4'),('Item_Quantity_Inventory', 'f4'),('GIV_Data_Entry_Date', 'M')])
    GIV = pd.DataFrame(GIV_data)

    GIV.loc[3,'Store_ID'] = '1'
    GIV.loc[3,'Item_ID'] = 'A1'
    GIV.loc[3,'Item_Name'] = 'Black dress A1'
    GIV.loc[3,'Item_Price'] = 100.0
    GIV.loc[3,'Item_Discount'] = 30.0
    GIV.loc[3,'Item_Quantity_Sold'] = 1.0
    GIV.loc[3,'Item_Quantity_Inventory'] = 22.0
    GIV.loc[3,'Item_Quantity_Ordered'] = 5.0
    GIV.loc[3,'GIV_Data_Entry_Date'] = datetime.datetime.strptime('2017-01-1', '%Y-%m-%d')

    GIV.loc[2,'Store_ID'] = '1'
    GIV.loc[2,'Item_ID'] = 'A1'
    GIV.loc[2,'Item_Name'] = 'Black dress A1'
    GIV.loc[2,'Item_Price'] = 100.0
    GIV.loc[2,'Item_Discount'] = 20.0
    GIV.loc[2,'Item_Quantity_Sold'] = 1.0
    GIV.loc[2,'Item_Quantity_Inventory'] = 18.0
    GIV.loc[2,'Item_Quantity_Ordered'] = 5.0
    GIV.loc[2,'GIV_Data_Entry_Date'] = datetime.datetime.strptime('2016-12-1', '%Y-%m-%d')

    GIV.loc[1,'Store_ID'] = '1'
    GIV.loc[1,'Item_ID'] = 'A1'
    GIV.loc[1,'Item_Name'] = 'Black dress A1'
    GIV.loc[1,'Item_Price'] = 100.0
    GIV.loc[1,'Item_Discount'] = 10.0
    GIV.loc[1,'Item_Quantity_Sold'] = 1.0
    GIV.loc[1,'Item_Quantity_Inventory'] = 14.0
    GIV.loc[1,'Item_Quantity_Ordered'] = 5.0
    GIV.loc[1,'GIV_Data_Entry_Date'] = datetime.datetime.strptime('2016-11-1', '%Y-%m-%d')

    GIV.loc[0,'Store_ID'] = '1'
    GIV.loc[0,'Item_ID'] = 'A1'
    GIV.loc[0,'Item_Name'] = 'Black dress A1'
    GIV.loc[0, 'Item_Price'] = 100.0
    GIV.loc[0,'Item_Discount'] = 0.0
    GIV.loc[0,'Item_Quantity_Sold'] = 1.0
    GIV.loc[0,'Item_Quantity_Inventory'] = 10.0
    GIV.loc[0,'Item_Quantity_Ordered'] = 5.0
    GIV.loc[0,'GIV_Data_Entry_Date'] = datetime.datetime.strptime('2016-10-1', '%Y-%m-%d')

    Census_data = np.zeros((1,),dtype=[('Store_Postal_Code', 'a10'), ('Total_population', 'i4'), ('Other_race_percent', 'f4'), ('White_race_percent', 'f4'),('American_native_race_percent', 'f4'),('Black_race_percent', 'f4'),('Asian_race_percent', 'f4'), ('Male_percent', 'f4'),('Male_median_age', 'f4'), ('Female_percent', 'f4'),('Female_median_age', 'f4'),('Census_Data_Entry_Date', 'M')]) 
                  
#print(Census_data)

    Census = pd.DataFrame(Census_data)

    Census.loc[0,'Total_population'] =62228
    Census.loc[0,'Store_Postal_Code'] ='95123'

    Census.loc[0,'White_race_percent'] = 55.9
    Census.loc[0,'Black_race_percent'] = 4.2
    Census.loc[0,'American_native_race_percent'] = 1.1
    Census.loc[0,'Asian_race_percent'] = 18.8
    Census.loc[0,'Other_race_percent'] =19.7

    Census.loc[0,'Male_percent'] = 49.2
    Census.loc[0,'Male_median_age'] = 34.9

    Census.loc[0,'Female_percent'] = 50.8
    Census.loc[0,'Female_median_age'] = 36.9

    Census.loc[0,'Census_Data_Entry_Date'] = datetime.datetime.strptime('2010-12-31', '%Y-%m-%d') 

    
    df=Esos
    df = df.merge(PDB,on='Employee_ID',how='left')
    #print(df)

    df = df.merge(GIV,on='Item_ID',how='left')
    #print(df)

    df = df[(df.GIV_Data_Entry_Date >= df.Start_Date) & (df.GIV_Data_Entry_Date <= df.End_Date)]
    
    #print('Final df')        
    #print(df)    
            
    Census_Data_Start_Date = datetime.datetime.strptime('2009-12-31', '%Y-%m-%d') 
    Census = Census[Census.Census_Data_Entry_Date >= Census_Data_Start_Date]         #To be sure the latest Census data is captured
    #print(Census)
    
    df = df.merge(Census, on='Store_Postal_Code',how='left')
    #print(df)

    i=datetime.datetime.now()
    print("\n \n \n \n Report to the inventory manager as of %s-%s-%s" % (i.month, i.day, i.year))
    print('_____________________________________________________________________________________________')
    
    import matplotlib.pyplot 
    import datetime as dt


    x1=df['GIV_Data_Entry_Date']
    y1 =df['Item_Quantity_Sold']

    x2=x1
    y2 =df['Item_Price'] - df['Item_Discount']

    x3=x1
    y3=df['Item_Quantity_Inventory']

          
    x4=x1
    y4 =df['Item_Discount']

# y = range(len(x)) # many thanks to Kyss Tao for setting me straight here
    import matplotlib.pyplot as plt
    import matplotlib.dates as mdates

#fig, axes = plt.subplots(nrows=4, ncols=1)


    fig = plt.figure()
    ax1 = fig.add_subplot(211)
    ax2 = fig.add_subplot(212)
#ax3 = fig.add_subplot(213)
#ax4 = fig.add_subplot(214)

    ax1.title.set_text('Items Sold')
    ax2.title.set_text('Effective price = Price - Discount')
#ax3.title.set_text('Inventories')
#ax4.title.set_text('Discount applied')



    plt.subplot(211)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    plt.tight_layout()
    plt.plot(x1, y1, 'bo', linestyle='--')

    plt.subplot(212)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    plt.tight_layout()
    plt.plot(x2, y2, 'bo', linestyle='--')


    plt.show()


    fig = plt.figure()
    ax1 = fig.add_subplot(211)
    ax2 = fig.add_subplot(212)

    ax1.title.set_text('Inventories')
    ax2.title.set_text('Discount applied')



    plt.subplot(211)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    plt.tight_layout()
    plt.plot(x3, y3, 'bo', linestyle='--')

    plt.subplot(212)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    plt.tight_layout()
    plt.plot(x4, y4, 'bo', linestyle='--')


    plt.show()

    import matplotlib.pyplot as plt


    print('\n Racial Mix in the store postal code area, US Census 2010')
    print('_____________________________________________________________________________________________')

    # Pie chart, where the slices will be ordered and plotted counter-clockwise:
    labels = 'White', 'Black', 'Native American', 'Asian', 'Other'
    #sizes = [15, 30, 45, 10]
    sizes = [Census.loc[0,'White_race_percent'],
    Census.loc[0,'Black_race_percent'],
    Census.loc[0,'American_native_race_percent'],
    Census.loc[0,'Asian_race_percent'],
    Census.loc[0,'Other_race_percent']]
    explode = (0, 0, 0, 0.1, 0)  

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
    shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

    plt.show()

    # Pie chart, where the slices will be ordered and plotted counter-clockwise:
    print('\n Gender mix in the store postal code area, US Census 2010')
    print('_____________________________________________________________________________________________')
    labels = 'Female', 'Male'
    sizes = [Census.loc[0,'Female_percent'],
    Census.loc[0,'Male_percent']]
    explode = (0, 0)  

    fig1, ax1 = plt.subplots()
    ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

    print('\n Table. Details on sales reported by the employee')
    print('_____________________________________________________________________________________________')
    df_report3= df.ix[:,['Employee_Openion', 'Employee_Openion_text', 'Store_ID_x','Item_ID', 'Item_Name', 'GIV_Data_Entry_Date','Item_Price', 'Item_Discount','Item_Quantity_Sold', 'Item_Quantity_Ordered', 'Item_Quantity_Inventory']]
    print(df_report3)
    
  
    
    
    print("\n Reference Store information:")
    print('____________________________________________')
    df_report1= df.ix[0,['Store_Name', 'Store_ID_x', 'Store_Street_Address', 'Store_City', 'Store_State', 'Store_Postal_Code']]
    print(df_report1)
    
    print("\n Reference Employee information:")
    print('________________________________')
    df_report2= df.ix[0,['Employee_ID', 'Employee_First_Name', 'Employee_Middle_Name', 'Employee_Last_Name']]
    #df_report2.head()
    print(df_report2)   
    
Esos_function()
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# Hi,
# Welcome to Kohl's!
# We need to know your openion on sales in your department to account for it in our re-stocking plans.
# Enter commodity you want to talk about
#  > A1
# Enter your Kohl's employee card
#  > 1111
# What is the start of the period you wanted to talk about in format
#    MM-DD-YYYY?
#  > 01-01-2015
# What is the end of the period you wanted to talk about in format
#    MM-DD-YYYY?
#  > 02-01-2017
# What is your openion on sales of this item?
#  a) Well
#  b) Poorly
# >   poorly
# Please, provide your free text feedback
# >   The design is bad
#
#
#
#
#  Report to the inventory manager as of 2-6-2017
# _____________________________________________________________________________________________
# ...
